# %%
import anndata as ad 
pred_file = ad.read_h5ad("/mnt/shared-storage-user/lvying/s2-project/virtual_cell/PerturbNova/outputs/experiments/replogle_stage2_ablation_500k_20260408/zeroshot/hepg2/v1_500k_infer/cell_eval/pred_for_cell_eval.h5ad")
real_file = ad.read_h5ad("/mnt/shared-storage-user/lvying/s2-project/virtual_cell/PerturbNova/outputs/experiments/replogle_stage2_ablation_500k_20260408/zeroshot/hepg2/v1_500k_infer/cell_eval/real_for_cell_eval.h5ad")

# %%
pred_file[pred_file.obs['gene']=='KIAA1143'].X.mean(axis=0)
# Out:
# array([1.0720843 , 0.50419086, 0.15153557, ..., 1.7321097 , 3.6817768 ,
#        1.7756355 ], shape=(2000,), dtype=float32)

# %%
pred_file[pred_file.obs['gene']=='non-targeting'].X.mean(axis=0)
# Out:
# array([1.1975203 , 0.44570276, 0.13573565, ..., 1.8370332 , 3.8492517 ,
#        1.946808  ], shape=(2000,), dtype=float32)

# %%
real_file[pred_file.obs['gene']=='non-targeting'].X.mean(axis=0)
# Out:
# array([0.71678996, 0.4799581 , 0.15690748, ..., 1.0171187 , 2.9940834 ,
#        1.1008134 ], shape=(2000,), dtype=float32)
